# %%
import cv2
import os
import os.path as osp
import matplotlib.pyplot as plt
import numpy as np

# %%
 path = r'/home/csl/code/preprocess/data/S2Looking/val/label/72.png'
 path = r'/home/csl/code/preprocess/data/gaofen/trainData/gt_idx/1_1_label.png'
 img = cv2.imread(path)
 plt.matshow(img)

# %%
img.shape, img.dtype, np.unique(img)
# Out:
# ((512, 512, 3), dtype('uint8'), array([  0, 255], dtype=uint8))
